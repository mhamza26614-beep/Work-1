# %%
fastfoods = ["burger","pizza","fries","hotdog"]
print(len(fastfoods))
# Out:
# 4

# %%
Numbers = [1,2,4,8,16,32,64,128,150]
Total = sum(Numbers)
print(Total)
# Out:
# 405

# %%
Largest = max(Numbers)
print(Largest)
# Out:
# 150

# %%
Values = [22,98,1,76,21,9,13,34,85]
for num in Values:
    if num < 5:
        print(num)
# Out:
# 1
